# %%
import cv2

# %%
import numpy as np

# %% [markdown]
# # Read the image using OpenCV command

# %%
import cv2
dir(cv2)
# Out:
# ['ACCESS_FAST',
#  'ACCESS_MASK',
#  'ACCESS_READ',
#  'ACCESS_RW',
#  'ACCESS_WRITE',
#  'ADAPTIVE_THRESH_GAUSSIAN_C',
#  'ADAPTIVE_THRESH_MEAN_C',
#  'AGAST_FEATURE_DETECTOR_AGAST_5_8',
#  'AGAST_FEATURE_DETECTOR_AGAST_7_12D',
#  'AGAST_FEATURE_DETECTOR_AGAST_7_12S',
#  'AGAST_FEATURE_DETECTOR_NONMAX_SUPPRESSION',
#  'AGAST_FEATURE_DETECTOR_OAST_9_16',
#  'AGAST_FEATURE_DETECTOR_THRESHOLD',
#  'AKAZE',
#  'AKAZE_DESCRIPTOR_KAZE',
#  'AKAZE_DESCRIPTOR_KAZE_UPRIGHT',
#  'AKAZE_DESCRIPTOR_MLDB',
#  'AKAZE_DESCRIPTOR_MLDB_UPRIGHT',
#  'AKAZE_create',
#  'AffineFeature',
#  'AffineFeature_create',
#  'AgastFeatureDetector',
#  'AgastFeatureDetector_AGAST_5_8',
#  'AgastFeatureDetector_AGAST_7_12d',
#  'AgastFeatureDetector_AGAST_7_12s',
#  'AgastFeatureDetector_NONMAX_SUPPRESSION',
#  'AgastFeatureDetector_OAST_9_16',
#  'AgastFeatureDetector_THRESHOLD',
#  'AgastFeatureDetector_create',
#  'Algorithm',
#  'AlignExposures',
#  'AlignMTB',
#  'AsyncArray',
#  'BFMatcher',
# ...

# %% [markdown]
# # Convert color image to gray

# %%
image=cv2.imread("C:\\Users\\abhin\\Desktop\\Joseph_Siffrein_Duplessis_-_Benjamin_Franklin_-_Google_Art_Project.jpg")
print(image)
# Out:
# [[[ 25  29  30]
#   [ 39  43  44]
#   [ 30  34  35]
#   ...
#   [ 21  33  39]
#   [ 35  47  51]
#   [ 23  38  41]]
#
#  [[ 19  23  24]
#   [ 25  29  30]
#   [ 15  19  20]
#   ...
#   [ 22  32  39]
#   [ 42  54  58]
#   [ 44  59  62]]
#
#  [[ 22  26  27]
#   [ 18  22  23]
#   [  9  13  14]
#   ...
#   [ 37  48  52]
#   [ 45  57  61]
#   [ 43  55  59]]
#
#  ...
#
#  [[ 71 109 141]
#   [ 42  80 110]
#   [ 33  69  99]
#   ...
#   [ 15  19  20]
#   [ 25  29  30]
#   [ 12  16  17]]
#
#  [[107 148 181]
#   [ 71 112 144]
#   [ 74 113 145]
#   ...
#   [ 11  15  16]
#   [ 42  46  47]
#   [ 32  36  37]]
#
#  [[ 41  84 117]
#   [ 30  73 106]
#   [ 49  90 122]
#   ...
#   [ 13  17  18]
#   [ 19  23  24]
#   [ 17  21  22]]]

# %%
gray_img=cv2.cvtColor(image,
                     cv2.COLOR_BGR2GRAY)
# gray scale conversion

# %%
gray_img
# Out:
# array([[ 29,  43,  34, ...,  33,  47,  37],
#        [ 23,  29,  19, ...,  33,  54,  58],
#        [ 26,  22,  13, ...,  48,  57,  55],
#        ...,
#        [114,  85,  74, ...,  19,  29,  16],
#        [153, 117, 118, ...,  15,  46,  36],
#        [ 89,  78,  95, ...,  17,  23,  21]], dtype=uint8)

# %%
cv2.imshow('image',image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
cv2.imshow('image',gray_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
type(image)
# Out:
# numpy.ndarray

# %%
cropped_image=image[100:300, 250:320]

# %%
import matplotlib.pyplot as plt
plt.imshow(cropped_image)

# %%
image[100:300, 250:320]=(0,0,0)
plt.imshow(image)

# %%
olive=(128,128,0)
image[100:300, 250:320]=(128,128,0)
plt.imshow(image)

# %%
image
# Out:
# array([[[ 25,  29,  30],
#         [ 39,  43,  44],
#         [ 30,  34,  35],
#         ...,
#         [ 21,  33,  39],
#         [ 35,  47,  51],
#         [ 23,  38,  41]],
#
#        [[ 19,  23,  24],
#         [ 25,  29,  30],
#         [ 15,  19,  20],
#         ...,
#         [ 22,  32,  39],
#         [ 42,  54,  58],
#         [ 44,  59,  62]],
#
#        [[ 22,  26,  27],
#         [ 18,  22,  23],
#         [  9,  13,  14],
#         ...,
#         [ 37,  48,  52],
#         [ 45,  57,  61],
#         [ 43,  55,  59]],
#
#        ...,
#
#        [[ 71, 109, 141],
#         [ 42,  80, 110],
#         [ 33,  69,  99],
#         ...,
#         [ 15,  19,  20],
#         [ 25,  29,  30],
#         [ 12,  16,  17]],
#
#        [[107, 148, 181],
#         [ 71, 112, 144],
#         [ 74, 113, 145],
#         ...,
#         [ 11,  15,  16],
#         [ 42,  46,  47],
#         [ 32,  36,  37]],
#
#        [[ 41,  84, 117],
#         [ 30,  73, 106],
#         [ 49,  90, 122],
# ...

# %%
M=np.float32([[1,0,230],[0,1,400]])
M
# Out:
# array([[  1.,   0., 230.],
#        [  0.,   1., 400.]], dtype=float32)

# %%
shifted = cv2.warpAffine(image,M,(image.shape[1],image.shape[0]))
plt.imshow(shifted)

# %%
M=np.float32([[1,0,-30],[0,1,-200]])
shifted = cv2.warpAffine(image,M,(image.shape[1],image.shape[0]))
plt.imshow(shifted)

# %%
(height,width,channels)=image.shape
centre=(width//2,height//2)
centre
# Out:
# (600, 732)

# %%
M = cv2.getRotationMatrix2D(centre,45,0.5)
rotated=cv2.warpAffine(image,M,(width,height))
plt.imshow(rotated)

# %%
M = cv2.getRotationMatrix2D(centre,90,1.0)
rotated = cv2.warpAffine(image,M,(width,height))
plt.imshow(rotated)

# %%
M = cv2.getRotationMatrix2D(centre,180,1.0)
rotated=cv2.warpAffine(image,M,(width,height))
plt.imshow(rotated)

# %%
# flipping along x and axes
flipped = cv2.flip(image,-1)
plt.imshow(flipped)

# %% [markdown]
# # Cropping

# %% [markdown]
# - We will now see an example of cropping yhe image toget the head only

# %%
image.shape
# Out:
# (1464, 1200, 3)

# %%
cropped_image=image[50:320,250:430]
plt.imshow(cropped_image)

# %%
# Create a new video stream and get total frame count
video_stream = cv2.VideoCapture('image/face.mp4')
total_frames = video_stream.get(cv2.CAP_PROP_FRAME_COUNT)
total_frames
# Out:
# 0.0
