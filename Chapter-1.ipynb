# %%
import cv2

# %% [markdown]
# # Method-1

# %% [markdown]
# - Using opencv method
# - When you read image,it will open a new window
# - And image will display on the window
# - If you want to close the window press: 0

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\abhin\\Documents\\Untitled Folder'

# %%
import cv2
image=cv2.imread("C:\\Users\\abhin\\Desktop\\Joseph_Siffrein_Duplessis_-_Benjamin_Franklin_-_Google_Art_Project.jpg")
image
# Out:
# array([[[ 25,  29,  30],
#         [ 39,  43,  44],
#         [ 30,  34,  35],
#         ...,
#         [ 21,  33,  39],
#         [ 35,  47,  51],
#         [ 23,  38,  41]],
#
#        [[ 19,  23,  24],
#         [ 25,  29,  30],
#         [ 15,  19,  20],
#         ...,
#         [ 22,  32,  39],
#         [ 42,  54,  58],
#         [ 44,  59,  62]],
#
#        [[ 22,  26,  27],
#         [ 18,  22,  23],
#         [  9,  13,  14],
#         ...,
#         [ 37,  48,  52],
#         [ 45,  57,  61],
#         [ 43,  55,  59]],
#
#        ...,
#
#        [[ 71, 109, 141],
#         [ 42,  80, 110],
#         [ 33,  69,  99],
#         ...,
#         [ 15,  19,  20],
#         [ 25,  29,  30],
#         [ 12,  16,  17]],
#
#        [[107, 148, 181],
#         [ 71, 112, 144],
#         [ 74, 113, 145],
#         ...,
#         [ 11,  15,  16],
#         [ 42,  46,  47],
#         [ 32,  36,  37]],
#
#        [[ 41,  84, 117],
#         [ 30,  73, 106],
#         [ 49,  90, 122],
# ...

# %%
import cv2
image=cv2.imread("C:\\Users\\abhin\\Desktop\\Joseph_Siffrein_Duplessis_-_Benjamin_Franklin_-_Google_Art_Project.jpg")
cv2.imshow("benjiman",image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Method-2

# %% [markdown]
# - Using google colab notebook
# - Run below codes in google colab only

# %%
from google.colab.patches import cv2_imshow
import cv2
image = cv2.imread("continents/Joseph_Siffrein_Duplessis_-_Benjamin_Franklin_-_Google_Art_Project.jpg")
cv2_imshow(image)

# %% [markdown]
# # Method-3

# %% [markdown]
# - Using Pillow Package

# %%
from PIL import Image
image=Image.open("C:\\Users\\abhin\\Desktop\\Joseph_Siffrein_Duplessis_-_Benjamin_Franklin_-_Google_Art_Project.jpg")
image.show()

# %% [markdown]
# # Method-4

# %% [markdown]
# - open using matplotlib

# %%
import matplotlib.pyplot as plt
from PIL import Image
image=Image.open("C:\\Users\\abhin\\Desktop\\Joseph_Siffrein_Duplessis_-_Benjamin_Franklin_-_Google_Art_Project.jpg")
plt.imshow(image)

# %% [markdown]
# **Writiing image**

# %%
import cv2
image=cv2.imread("C:\\Users\\abhin\\Desktop\\Joseph_Siffrein_Duplessis_-_Benjamin_Franklin_-_Google_Art_Project.jpg")
cv2.imwrite('output.jpg',image)
cv2.imwrite('output.png',image)
# Out:
# True
